# %% [markdown]
# API - Application Programming Interface

# %%
# Installing the Kaggle Library

# !pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.7.4.5-py3-none-any.whl.metadata (16 kB)
# Collecting bleach (from kaggle)
#   Using cached bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting certifi>=14.05.14 (from kaggle)
#   Using cached certifi-2025.6.15-py3-none-any.whl.metadata (2.4 kB)
# Collecting charset-normalizer (from kaggle)
#   Using cached charset_normalizer-3.4.2-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Collecting idna (from kaggle)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting protobuf (from kaggle)
#   Using cached protobuf-6.31.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: python-dateutil>=2.5.3 in d:\# my learning\coding\machine-learning-tutorial\.venv\lib\site-packages (from kaggle) (2.9.0.post0)
# Collecting python-slugify (from kaggle)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting requests (from kaggle)
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting setuptools>=21.0.0 (from kaggle)
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: six>=1.10 in d:\# my learning\coding\machine-learning-tutorial\.venv\lib\site-packages (from kaggle) (1.17.0)
# Collecting text-unidecode (from kaggle)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting tqdm (from kaggle)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting urllib3>=1.15.1 (from kaggle)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting webencodings (from kaggle)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: colorama in d:\# my learning\coding\machine-learning-tutorial\.venv\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Downloading kaggle-1.7.4.5-py3-none-any.whl (181 kB)
# Using cached certifi-2025.6.15-py3-none-any.whl (157 kB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached bleach-6.2.0-py3-none-any.whl (163 kB)
# Using cached charset_normalizer-3.4.2-cp312-cp312-win_amd64.whl (105 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached protobuf-6.31.1-cp310-abi3-win_amd64.whl (435 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Installing collected packages: webencodings, text-unidecode, urllib3, tqdm, setuptools, python-slugify, protobuf, idna, charset-normalizer, certifi, bleach, requests, kaggle
#
#    ----------------------------------------  0/13 [webencodings]
#    ----------------------------------------  0/13 [webencodings]
#    --- ------------------------------------  1/13 [text-unidecode]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    ------ ---------------------------------  2/13 [urllib3]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    --------- ------------------------------  3/13 [tqdm]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    ------------ ---------------------------  4/13 [setuptools]
#    --------------- ------------------------  5/13 [python-slugify]
#    --------------- ------------------------  5/13 [python-slugify]
#    --------------- ------------------------  5/13 [python-slugify]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    ------------------ ---------------------  6/13 [protobuf]
#    --------------------- ------------------  7/13 [idna]
#    --------------------- ------------------  7/13 [idna]
#    --------------------- ------------------  7/13 [idna]
#    --------------------- ------------------  7/13 [idna]
#    --------------------- ------------------  7/13 [idna]
#    --------------------- ------------------  7/13 [idna]
#    ------------------------ ---------------  8/13 [charset-normalizer]
#    ------------------------ ---------------  8/13 [charset-normalizer]
#    ------------------------ ---------------  8/13 [charset-normalizer]
#    ------------------------ ---------------  8/13 [charset-normalizer]
#    ------------------------ ---------------  8/13 [charset-normalizer]
#    ------------------------ ---------------  8/13 [charset-normalizer]
#    --------------------------- ------------  9/13 [certifi]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    ------------------------------ --------- 10/13 [bleach]
#    --------------------------------- ------ 11/13 [requests]
#    --------------------------------- ------ 11/13 [requests]
#    --------------------------------- ------ 11/13 [requests]
#    --------------------------------- ------ 11/13 [requests]
#    --------------------------------- ------ 11/13 [requests]
#    --------------------------------- ------ 11/13 [requests]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ------------------------------------ --- 12/13 [kaggle]
#    ---------------------------------------- 13/13 [kaggle]
#
# Successfully installed bleach-6.2.0 certifi-2025.6.15 charset-normalizer-3.4.2 idna-3.10 kaggle-1.7.4.5 protobuf-6.31.1 python-slugify-8.0.4 requests-2.32.4 setuptools-80.9.0 text-unidecode-1.3 tqdm-4.67.1 urllib3-2.5.0 webencodings-0.5.1

# %% [markdown]
# # Upload your Kaggle.json File

# %%
# Configuring the path of Kaggle.json file

# %% [markdown]
# # Importing The Earthquake Dataset

# %%
#API to fetch the dataset from kaggle
# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# Downloading LANL-Earthquake-Prediction.zip to d:\# My Learning\Coding\Machine-Learning-Tutorial\Day 9
#   0%|          | 0.00/2.27G [00:00<?, ?B/s]
#   3%|▎         | 60.0M/2.27G [00:00<00:03, 629MB/s]
#   6%|▌         | 129M/2.27G [00:00<00:03, 684MB/s]
#   9%|▊         | 198M/2.27G [00:00<00:03, 702MB/s]
#  11%|█▏        | 265M/2.27G [00:02<00:23, 91.1MB/s]
#  15%|█▍        | 340M/2.27G [00:02<00:15, 138MB/s]
#  18%|█▊        | 410M/2.27G [00:02<00:10, 190MB/s]
#  20%|██        | 469M/2.27G [00:04<00:28, 68.4MB/s]
#  24%|██▎       | 548M/2.27G [00:04<00:18, 102MB/s]
#  26%|██▌       | 601M/2.27G [00:06<00:27, 64.7MB/s]
#  29%|██▊       | 664M/2.27G [00:06<00:19, 88.9MB/s]
#  31%|███       | 717M/2.27G [00:06<00:15, 109MB/s]
#  33%|███▎      | 757M/2.27G [00:09<00:36, 44.8MB/s]
#  36%|███▌      | 830M/2.27G [00:09<00:22, 68.5MB/s]
#  39%|███▉      | 909M/2.27G [00:09<00:14, 102MB/s]
#  41%|████▏     | 962M/2.27G [00:11<00:21, 65.6MB/s]
#  45%|████▍     | 1.01G/2.27G [00:11<00:14, 95.6MB/s]
#  48%|████▊     | 1.08G/2.27G [00:11<00:09, 128MB/s]
#  50%|████▉     | 1.13G/2.27G [00:13<00:17, 69.6MB/s]
#  53%|█████▎    | 1.21G/2.27G [00:13<00:11, 102MB/s]
#  55%|█████▌    | 1.25G/2.27G [00:15<00:18, 58.0MB/s]
#  58%|█████▊    | 1.32G/2.27G [00:15<00:11, 85.0MB/s]
#  61%|██████    | 1.39G/2.27G [00:16<00:08, 116MB/s]
#  63%|██████▎   | 1.44G/2.27G [00:18<00:14, 60.4MB/s]
#  66%|██████▌   | 1.50G/2.27G [00:18<00:09, 83.5MB/s]
#  69%|██████▊   | 1.56G/2.27G [00:18<00:06, 113MB/s]
#  71%|███████   | 1.61G/2.27G [00:21<00:14, 48.6MB/s]
#  74%|███████▍  | 1.69G/2.27G [00:21<00:08, 75.8MB/s]
#  78%|███████▊  | 1.76G/2.27G [00:21<00:05, 105MB/s]
#  79%|███████▉  | 1.81G/2.27G [00:23<00:09, 52.8MB/s]
#  83%|████████▎ | 1.88G/2.27G [00:24<00:05, 77.7MB/s]
#  86%|████████▌ | 1.95G/2.27G [00:24<00:03, 104MB/s]
#  88%|████████▊ | 1.99G/2.27G [00:26<00:04, 62.0MB/s]
#  91%|█████████ | 2.06G/2.27G [00:26<00:02, 90.0MB/s]
#  93%|█████████▎| 2.10G/2.27G [00:26<00:01, 97.5MB/s]
#  94%|█████████▍| 2.14G/2.27G [00:27<00:02, 59.8MB/s]
#  97%|█████████▋| 2.21G/2.27G [00:28<00:00, 94.8MB/s]
#  99%|█████████▉| 2.25G/2.27G [00:30<00:00, 50.2MB/s]
# 100%|██████████| 2.27G/2.27G [00:30<00:00, 80.6MB/s]

# %%
# Extracting the compressed Dataset

from zipfile import ZipFile

dataset = 'LANL-Earthquake-Prediction.zip'

with ZipFile(dataset, 'r') as zip:
    zip.extractall()
    print("Dataset is Extracted")
# Out:
# Dataset is Extracted
