# %% [markdown]
# # Importing Dependencies

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Dot Product of 2 Vectors

# %%
a = np.array([2,3])

b = np.array([4,4])

dot_product = np.dot(a,b)

# %%
print(dot_product)
# Out:
# 20

# %%
c = np.array([40,20,35])
d = np.array([53,24,68])

dot_product = np.dot(c,d)

# %%
print(dot_product)
# Out:
# 4980
