# %% [markdown]
# # Importing Dependencies

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Euclidean Distance

# %% [markdown]
# ![Picture1.png](data:image/png;base64,...)

# %%
# consider two points with 2d

p1 = (1,1)
p2 = (2,2)

# %%
# Calculating Euclidean Distance 

dist = (p1[0] - p2[0])**2 + (p1[1] - p2[1])**2

euclidean = np.sqrt(dist)
print("Euclidean Distance :", euclidean)
# Out:
# Euclidean Distance : 1.4142135623730951

# %%
# Consider three points with 3d

p1 = (1,1,1)
p2 = (2,2,2)

# Calculating Euclidean Distance

dist = (p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2

euclidean = np.sqrt(dist)
print("Euclidean Distance :", euclidean)
# Out:
# Euclidean Distance : 1.7320508075688772

# %%
# Consider four points in 4d

p1 = (1,1,1,1)
p2 = (2,2,2,2)

dist = 0

for i in range(len(p1)):
    dist = dist + (p1[i] - p2[i])**2


euclidean_dist = np.sqrt(dist)
print(euclidean_dist)
# Out:
# 2.0

# %%
# Creating a function to calculate Euclidean distance


def cal_euclidean_dist(p1,p2):

    dist = 0 

    for i in range(len(p1)):
        dist = dist + (p1[i] - p2[i])**2


    euclidean_dist = np.sqrt(dist)
    print("Euclidean Distance is :", euclidean_dist)

# %%
cal_euclidean_dist((12,43,12), (2,2,2))
# Out:
# Euclidean Distance is : 43.37049688440288
