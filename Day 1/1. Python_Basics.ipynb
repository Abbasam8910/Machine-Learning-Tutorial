# %% [markdown]
# Programming Lanuges used in Machine Learning
# - Python
# - R

# %% [markdown]
# # Print Function

# %%
print("Machine Learning")
# Out:
# Machine Learning

# %%
print("Hi" + " Welcome" + " To" + " Machine Learning" + " Tutorial")
# Out:
# Hi Welcome To Machine Learning Tutorial

# %%
print(8)  # only strings need to add in quotes
# Out:
# 8

# %%
print(4+6)
# Out:
# 10

# %% [markdown]
# # Basic Data Types:
#
# 1. int
# 2. float
# 3. str

# %%
type(8)
# Out:
# int

# %%
type(13.3)
# Out:
# float

# %%
type("welcome")
# Out:
# str

# %% [markdown]
# # Constants and Variables

# %%
string_variable="Hi"

num_variable=12

float_variable=12.3

print(string_variable)
print(num_variable)
print(float_variable)
# Out:
# Hi
# 12
# 12.3

# %%
string_variable="Welcome"

print(string_variable)
# Out:
# Welcome

# %%
var1, var2, var3 = 1, 3, 5

print(var2)
# Out:
# 3

# %%
hero1, hero2, hero3 = "Iron Man", "Captain America", "Bat Man"

print(hero1)
print(hero2)
print(hero3)
# Out:
# Iron Man
# Captain America
# Bat Man

# %%
x = y= z = 43

print(x)
print(y)
print(z)
# Out:
# 43
# 43
# 43

# %% [markdown]
# # Input Function

# %%
num1= int(input("Enter the first number: "))
num2 = int(input("Enter the second number"))

sum=num1+num2

print(f"Sum of {num1} and {num2} is : ",sum)
# Out:
# Sum of 20 and 10 is :  30

# %%
# Changing the data type in python:

num = 5

type(num)
# Out:
# int

# %%
print(float(num))
# Out:
# 5.0
