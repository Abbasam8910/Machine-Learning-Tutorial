# %% [markdown]
# # Importing Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()  # To load basic default themes for our charts

# %% [markdown]
# # Plotting a Vector

# %%
plt.quiver(0,0,4,5)
plt.show()

# %% [markdown]
# Our plot is not plotting correctly so we will mention x and y properly

# %%
plt.quiver(0,0, 4,5, scale_units = 'xy', angles = 'xy', scale =1, color='r') # (0,0) -> base point
plt.quiver(0,0, -3,-6, scale_units = 'xy', angles = 'xy', scale =1, color='y') 
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# # Addition of Two Vectors

# %%
vector_1 = np.asarray([0,0, 2,3])
vector_2 = np.asarray([0,0, 3, -2])

sum = vector_1 + vector_2

print(sum)
# Out:
# [0 0 5 1]

# %%
#  Ploting above three vectors

plt.quiver(0,0, 2,3, scale_units = 'xy', angles = 'xy', scale =1, color='r') # (0,0) -> base point
plt.quiver(0,0, 3,-2, scale_units = 'xy', angles = 'xy', scale =1, color='y') 
plt.quiver(0,0, 5,1, scale_units = 'xy', angles = 'xy', scale =1, color='b')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# # Subtraction of Two Vectors

# %%
vector_1 = np.asarray([0,0, 2,3])
vector_2 = np.asarray([0,0, 3, -2])

subtraction = vector_1 - vector_2

print(subtraction)
# Out:
# [ 0  0 -1  5]

# %%
plt.quiver(0,0, 2,3, scale_units = 'xy', angles = 'xy', scale =1, color='r') # (0,0) -> base point
plt.quiver(0,0, 3,-2, scale_units = 'xy', angles = 'xy', scale =1, color='y') 
plt.quiver(0,0, -1,5, scale_units = 'xy', angles = 'xy', scale =1, color='b')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# # Multiplying a Vector by a Scalar

# %%
vector_1 = np.asarray([0,0, 2,3])

vector_2 = 2* vector_1

print(vector_2)
# Out:
# [0 0 4 6]

# %%
plt.quiver(0,0, 2,3, scale_units = 'xy', angles = 'xy', scale =1, color='r') # (0,0) -> base point
plt.quiver(0,0, 4,6, scale_units = 'xy', angles = 'xy', scale =1, color='b')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %%
# Now for negative Numbers

vector_1 = np.asarray([0,0, 2,3])

vector_2 = -0.5* vector_1

print(vector_2)
# Out:
# [-0.  -0.  -1.  -1.5]

# %%
plt.quiver(0,0, 2,3, scale_units = 'xy', angles = 'xy', scale =1, color='r') # (0,0) -> base point
plt.quiver(0,0, -1,-1.5, scale_units = 'xy', angles = 'xy', scale =1, color='b')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()
